# %% [markdown]
# <a href="https://colab.research.google.com/github/Whitedevil015/DATA-SCIENCE/blob/main/Mall%20Customers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
from google.colab import files
uploaded=files.upload()
df=pd.read_csv("Mall_Customers.csv")
print(df.head())
# Out:
#      <input type="file" id="files-dd4e3797-9c5a-40a5-a573-aeca4dd75b09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd4e3797-9c5a-40a5-a573-aeca4dd75b09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.info())
sns.pairplot(df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
Plt. Scatter (df ['stige'], df [ Annual Income (KS)'])
Plt. x label('A')
Plly labell' Annual Income)
plt.show

# %%
plt.scatter(df['Age'],df['Annual Income (k$)']) # Changed 'age' to 'Age' and 'Annual Income (K$)' to 'Annual Income (k$)'
plt.xlabel('A')
plt.ylabel('Annual Income')
plt.show()

# %%
plt.scatter(df['Annual Income (k$)'],df['Spending Score (1-100)']) # Changed 'Annual Income (K$)' to 'Annual Income (k$)' and 'Spending score (1-100)' to 'Spending Score (1-100)'
plt.xlabel('Annual Income')
plt.ylabel('Spending Score') # Changed 'Spending score' to 'Spending Score'
plt.show()
plt.show()

# %%
Wcss=[]
for i in range(1,11):
    KMeans=KMeans(n_clusters=i)
    KMeans.fit(x)
    Wcss.append(KMeans.inertia_)
plt.plot(range(1,11),Wcss)
plt.title('The Elbow method')
plt.xlabel('Number of cluster')
plt.ylabel('wcss')
plt.show()
Wcss.append(KMeans,inertia_)
plt.plot(range(1,11),Wcss)
plt.tittle('The Elbow method')
plt.xlabel('Number of cluster')
plt.ylabel('wcss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-7ece578f72ea> in <cell line: 0>()
#       2 for i in range(1,11):
#       3     KMeans=KMeans(n_clusters=i)
# ----> 4     KMeans.fit(x)
#       5     Wcss.append(KMeans.inertia_)
#       6 plt.plot(range(1,11),Wcss)
#
# NameError: name 'x' is not defined
